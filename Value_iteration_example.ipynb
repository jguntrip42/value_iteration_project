# %% [markdown]
# ## Setup

# %% [markdown]
# We would suggest the following procedure for installing the package vi_algorithm.

# %% [markdown]
# Firstly, start pyenv and make a new Python environment. Then, to install the package from GitHub, run the following in the terminal (in your activated Python environment):

# %% [raw]
# python -m pip install 'git+https://github.com/jguntrip42/value_iteration_project'

# %% [markdown]
# While pyenv is still running, check that the script is performing properly by running

# %% [raw]
# pytest

# %% [markdown]
# in the terminal (two unit tests are run to check the program is functioning correctly).

# %% [markdown]
# Use the following code to import the function val_iteration from the Python script vi_4 into your own script:

# %%
from vi_algorithm.vi_4 import *

# %% [markdown]
# ## Grid World Problem Example

# %% [markdown]
# We can then setup some example data (for the grid world problem) to test our script on.

# %%
example_data_dict =  {
               'TLRTR': [0.9,-1],
               'TLRBL': [0.1, -2],
               'TLDBL': [0.9, -2],
               'TLDTR': [0.1, -1],
               'TRLTL': [0.9, -3/2],
               'TRLBR': [0.1, 10],
               'TRDBR': [0.8, 15],
               'TRDTL': [0.2, -1],
               'BLRBR': [0.9, 20],
               'BLRTL': [0.1, -5/2],
               'BLUTL': [0.8, -1/2],
               'BLUBR': [0.2, 5]}


example_S = ['TL','TR','BL','BR']
example_A = ['R','L','U','D']


def P_0(s_new,s,a):
    
    if ((s+a+s_new) in example_data_dict):
        p = example_data_dict[s+a+s_new][0]
    else:
        p = 0
    
    return p

def R_0(s_new,s,a):
    
    return example_data_dict[s+a+s_new][1]

# %% [markdown]
# Having defined the various input data structures and functions, we can then run the example using the following code (note that we set gamma=0.9, prioritising long term rewards over short term gains).

# %%
pi_0, val_maps_0 = val_iteration(example_S,example_A,P_0,R_0,gamma=0.9)
pi_0
# Out:
# {'TL': 'D', 'TR': 'D', 'BL': 'R', 'BR': None}

# %%
val_maps_0
# Out:
# {'TL': 14.86378742883109,
#  'TR': 14.47531566016127,
#  'BL': 19.087657830080634,
#  'BR': 0}
